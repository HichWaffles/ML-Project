# %% [markdown]
# # Model Prediction Example
# This notebook demonstrates how to load saved testing data and run predictions using the `predict.py` script.

# %%
import sys
from pathlib import Path
import pandas as pd

# Ensure project root is in path
project_root = Path("..").resolve()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.predict import predict

# %%
# Load test data
data_dir = project_root / "data" / "train_test"
X_test = pd.read_csv(data_dir / "X_test.csv")

print("Test data shape:", X_test.shape)
X_test.head()
# Out:
# Test data shape: (875, 49)
#    Frequency  TotalQuantity  MaxQuantity  CustomerTenureDays  \
# 0  -0.228042      -0.033789    -0.060310            0.994000
# 1   0.219845      -0.188636    -0.062450            1.407654
# 2  -0.228042      -0.160866    -0.061023            0.572825
# 3  -0.004098      -0.117767    -0.009669            0.896227
# 4  -0.451986      -0.205743    -0.026787           -1.006582
#
#    FirstPurchaseDaysAgo  PreferredDayOfWeek  PreferredMonth  \
# 0              0.937226                   4        0.396247
# 1              0.819051                   3        0.971933
# 2              0.548937                   1       -1.618653
# 3              0.312587                   2        0.108404
# 4             -0.894485                   3        0.108404
#
#    WeekendPurchaseRatio  AvgDaysBetweenPurchases  UniqueDescriptions  ...  \
# 0               -0.4708                -0.191040            1.476855  ...
# 1               -0.4708                -0.017658            0.336044  ...
# 2               -0.4708                 0.390425           -0.444512  ...
# 3               -0.4708                 0.154596           -0.168315  ...
# 4               -0.4708                -0.306782           -0.672674  ...
#
#    ProductDiversity_Modéré  ProductDiversity_Spécialisé  Gender_Unknown  \
# 0                    False                        False           False
# 1                    False                        False            True
# 2                    False                        False           False
# 3                    False                        False           False
# 4                     True                        False           False
#
#    AccountStatus_Closed  AccountStatus_Suspended     GeoIP  RegistrationMonth  \
# 0                 False                    False  1.477219          -1.346434
# 1                 False                    False  0.056453           0.055817
# 2                 False                    False -1.104829          -0.224633
# 3                 False                    False  1.477219          -1.346434
# 4                 False                    False  1.477219           0.055817
#
#    RegistrationDay  RegistrationDayOfWeek  DaysSinceRegistration
# 0        -1.092599                      5               1.977663
# 1        -1.664749                      3               1.117665
# 2        -1.435889                      4              -0.881088
# 3        -0.520449                      3               1.948008
# 4        -0.520449                      0              -1.106466
#
# [5 rows x 49 columns]

# %%
# Run predictions
results = predict(X_test)

print("Prediction results shape:", results.shape)
results[["Churn_Prediction", "Churn_Probability"]].head(10)
# Out:
# Prediction results shape: (875, 51)
#    Churn_Prediction  Churn_Probability
# 0                 0           0.010056
# 1                 0           0.000127
# 2                 0           0.012711
# 3                 0           0.000000
# 4                 1           1.000000
# 5                 0           0.000129
# 6                 1           0.980000
# 7                 0           0.000129
# 8                 0           0.010000
# 9                 1           0.989167

# %% [markdown]
# ## Combining with Ground Truth (y_test)

# %%
y_test = pd.read_csv(data_dir / "y_test.csv")
results["Actual_Churn"] = y_test.values

# Show cases where model predicted churn (1)
results[results["Churn_Prediction"] == 1][["Actual_Churn", "Churn_Prediction", "Churn_Probability"]].head(10)
# Out:
#     Actual_Churn  Churn_Prediction  Churn_Probability
# 4              1                 1           1.000000
# 6              1                 1           0.980000
# 9              1                 1           0.989167
# 13             1                 1           0.999960
# 15             1                 1           0.999960
# 16             1                 1           0.985588
# 17             1                 1           1.000000
# 18             1                 1           1.000000
# 20             1                 1           0.989653
# 21             1                 1           0.997651
